# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

df = pd.read_csv('titanic.csv')
df.head()
children = df[df['Age'] < 16]
children.shape
children.hist()
living_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
living_children.hist()
not_surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 0)]
not_surviving_children.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb342e10790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342e44e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342e874d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb342ebcb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342f00210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342f34890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb342f6bf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342faf590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342faf5d0>]],
#       dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

df = pd.read_csv('titanic.csv')
df.head()
# women_and_children = df[(df['Sex'] == "female")or(df['Age'] < 16)]
# w_a_c_survival_rate = women_and_children['Survived'].value_counts(normalize=True) * 100
# w_a_c_survival_rate

# adult_men = df[(df['Sex'].str.match('male')) & (df['Age'] > 16)]
# a_m_survival_rate = adult_men['Survived'].value_counts(normalize=True) * 100
# a_m_survival_rate
# Out:
# '77%'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

df = pd.read_csv('titanic.csv')
df.head()
#children
children = df[df['Age'] < 16]
surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
child_chance_of_survival = surviving_children.shape[0] / children.shape[0]
format(child_chance_of_survival, ".0%")
#women
women = df[(df['Sex'] == 'female') & (df['Age'] > 16)]
surviving_women = df[(df['Sex'] == 'female') & (df['Age'] > 16) & (df['Survived'] == 1)]
women_chance_of_survival = surviving_women.shape[0] / women.shape[0]
format(women_chance_of_survival, ".00%")
# women_chance_of_survival

#men
men = df[(df["Sex"] == 'male')& (df["Age"]>16)]
surviving_men = df[(df["Sex"] == 'male')& (df["Age"]>16)& (df['Survived'] == 1)]
men_chance_of_survival = surviving_men.shape[0]/men.shape[0]
format(men_chance_of_survival, ".0%")
# Out:
# '18%'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

df = pd.read_csv('titanic.csv')
df.head()
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
x_axis = ["Children", "Women", "Men"]
data = [child_chance_of_survival, women_chance_of_survival, men_chance_of_survival]
ax.bar(x_axis, data)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

df = pd.read_csv('titanic.csv')
surviving_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Survived'] == 1)]
surviving_men.describe()
dead_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Survived'] == 0)]
dead_men.describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    71.000000      71.0  71.000000  71.000000  71.000000  71.000000
# mean    485.267606       1.0   1.873239  34.323944   0.267606   0.126761
# std     222.128789       0.0   0.955130  11.798032   0.476827   0.411602
# min      22.000000       1.0   1.000000  17.000000   0.000000   0.000000
# 25%     288.000000       1.0   1.000000  26.500000   0.000000   0.000000
# 50%     513.000000       1.0   1.000000  32.000000   0.000000   0.000000
# 75%     654.500000       1.0   3.000000  41.000000   0.500000   0.000000
# max     890.000000       1.0   3.000000  80.000000   2.000000   2.000000
#
#              Fare
# count   71.000000
# mean    46.731869
# std     85.316448
# min      0.000000
# 25%      8.050000
# 50%     26.550000
# 75%     54.270850
# max    512.329200

# %%
# FIRST VS. THIRD CLASS MEN
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

third_class_adult_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Pclass'] == 3)]
thrird_class_adult_men_survival_rate = third_class_adult_men['Survived'].value_counts(normalize=True) * 100
thrird_class_adult_men_survival_rate
# Out:
# 0    87.037037
# 1    12.962963
# Name: Survived, dtype: float64

# %%
# FIRST VS. THIRD CLASS MEN
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

first_class_adult_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Pclass'] == 1)]
first_class_adult_men_survival_rate = first_class_adult_men['Survived'].value_counts(normalize=True) * 100
first_class_adult_men_survival_rate
# Out:
# 0    62.244898
# 1    37.755102
# Name: Survived, dtype: float64

# %%
# THE DEAD
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

the_dead = df[df["Survived"] == 0]
the_dead.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb342425810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb342819cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3424283d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3435aed10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3436a0850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb3436d4ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb3437193d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb34374d890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb34374d8d0>]],
#       dtype=object)

# %%
# WOMEN AND MEN BY CLASS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sn

sn.barplot(x='Pclass', y='Survived', data=women)
sn.barplot(x='Pclass', y='Survived', hue="Sex", data=df)
sn.barplot(x='Sex', y='Survived', hue="Pclass", data=df)
